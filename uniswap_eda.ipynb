# %% [markdown]
# # Uniswap EDA

# %% [markdown]
# ## Imports

# %%
# <include-uniswap_eda/utils.py>

# %%
# <imports>
from datetime import datetime

import pandas as pd
import plotly.io as pio

from uniswap_eda import utils

pd.options.plotting.backend = "plotly"
pio.templates.default = "none"

from sgqlc.operation import Operation
from schema import schema
from sgqlc.endpoint.http import HTTPEndpoint

url = 'https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3'

endpoint = HTTPEndpoint(url)

# %% [markdown]
# ## Overview

# %% [markdown]
# This notebook is an exploration of how Uniswap-V3 works. My basic understanding at this point is that a pool consist of liquidity providers who add pairs of tokens to a pool to be exchanged in what are called swaps by users. Liquidity providers share the fees that are generated from users swapping tokens. The price at which tokens are swapped is determined by a constant product formula. The fees that are earned are distributed based on the amount of a liquidity that each provider provided for the amount of time that the price was between the ticks that liquidity provider was providing liquidity in.
#
# ### How is the uniswap price determined?
#
# By the constant product formula with a slippage percentage specified relative to a price from an off chain oracle.
#
# Get historical twap pricing from uniswap api and compare to pricing from
#
# ##

# %% [markdown]
# ## Resources

# %% [markdown]
# * [Help Center](https://help.uniswap.org/en/)
# * [Documentation](https://docs.uniswap.org/)
# * [Github](https://github.com/Uniswap/uniswap-v3-core)
# * [info.uniswap.org](https://info.uniswap.org)
# * [White Paper](https://uniswap.org/whitepaper-v3.pdf)
# * [Discord Channel](https://discord.com/channels/597638925346930701/597638926152499206)
# * [Strategy Simulator](https://defi-lab.xyz/uniswapv3simulator)
# * [Uniswap Prices Calculation](https://github.com/thanpolas/univ3prices)
# * [Subgraph Schema](https://github.com/Uniswap/uniswap-v3-subgraph/blob/main/schema.graphql)
# * [RFPs and Challenges](https://www.notion.so/RFPs-Challenges-3be614ba4e504b5caeee7b0159e64a42)
# * [Ethereum Strategies](https://twitter.com/_jamiis/status/1360322712414076931)

# %% [markdown]
# ## Exploration of a Single Pool

# %% [markdown]
# The GraphQL query below gets the largest v3 pool by total value locked in USD terms. This happens to be USD Coin (USDC) versus Wrapped Ether (WETH) (which is just original ether that was introduced before the ERC-20 standard, wrapped with an ERC-20 smart contract). This pool was created on 2021-05-04. [Here](https://info.uniswap.org/#/pools/0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8) is the link to the pool stats on info.uniswap.org. That site says as of 12:42 pacific on 2021-07-21 that total value locked was $252.88 million, which corresponds pretty closely to the value of 253801793.24 per `totalValueLockedUSD`. `totalValueLockedtoken0` and `totalValueLockedtoken1` are also quite similar.
#
# The fee amount for this pool is 0.3% and a total of $56,278,508 (`feesUSD`) in fees have been collected to date. The total volume (`volumeUSD`) in USD to date is $18,759,502,936, which is exactly 0.003. `feeTier` is in thousands to needs to get divided by 1e6 to get to the floating point representation.
#
# Tick spacing can be 10, 50 or 200, associated with the fee tiers for 0.05%, 0.3% and 1% see [subgraph](https://github.com/Uniswap/uniswap-v3-subgraph/blob/fd64afaca4926a476896c993c6f9ff895bf986c5/src/utils/tick.ts#L43).
#
# Things to be able to do:
#
# * Explore the Position data
# * Calculate liquidity for a tick from positions
# * Equate pool liquidity with tick liquidity for current tick
# * Explore functions for
# * Calculate time weighed average price from two accumulator values
# * Add latex formulas to tie out to python functions / results
# * Candlestick chart for prices
#
# ![USDC WETH Overview](usdc_weth_2021-07-21_12-43-15.png)

# %%
op = Operation(schema.Query)
pool = op.pool(id="0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8")
pool.__fields__(
    mints=False,
    burns=False,
    swaps=False,
    pool_hour_data=False,
    pool_day_data=False,
    ticks=False,
    collects=False
)
pool.token0.__fields__(
    symbol=True,
    name=True,
    decimals=True,
    total_supply=True
)
pool.token1.__fields__(
    symbol=True,
    name=True,
    decimals=True,
    total_supply=True
)
# pool_hour_data = pools.pool_hour_data(first=5, order_by="periodStartUnix", order_direction="desc").__fields__(pool=False)
# pool.ticks(first=5, order_by="tickIdx", order_direction="desc", where={"tick_idx_lt": -47546}).__fields__(pool=False)

pool = endpoint(op)["data"]["pool"]

# %%
pool
# Out:
# {'collectedFeesToken0': '0',
#  'collectedFeesToken1': '0',
#  'collectedFeesUSD': '0',
#  'createdAtBlockNumber': '12370624',
#  'createdAtTimestamp': '1620169800',
#  'feeGrowthGlobal0X128': '879608981722641786094544848009357',
#  'feeGrowthGlobal1X128': '352367575245191929105225043689586084123335',
#  'feeTier': '3000',
#  'feesUSD': '56765567.63281827206766270036625933',
#  'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#  'liquidity': '17846142292882053102',
#  'liquidityProviderCount': '0',
#  'observationIndex': '0',
#  'sqrtPrice': '1744634243657861946041054518206014',
#  'tick': '200004',
#  'token0': {'decimals': '6',
#   'name': 'USD Coin',
#   'symbol': 'USDC',
#   'totalSupply': '19312'},
#  'token0Price': '2062.293069916995817242368269060948',
#  'token1': {'decimals': '18',
#   'name': 'Wrapped Ether',
#   'symbol': 'WETH',
#   'totalSupply': '19848'},
#  'token1Price': '0.0004848971344505601671670196813582106',
#  'totalValueLockedETH': '127096.7459814601576682515930193351',
#  'totalValueLockedToken0': '112291780.92186',
#  'totalValueLockedToken1': '72646.783190100162135376',
#  'totalValueLockedUSD': '262110738.4465660701089972040927362',
#  'totalValueLockedUSDUntracked': '0',
#  'txCount': '141474',
#  'untrackedVolumeUSD': '18921855877.60609068922090012208656',
#  'volumeToken0': '18919411447.715855',
#  'volumeToken1': '7690453.026307561319380265',
#  'volumeUSD': '18921855877.60609068922090012208656'}

# %%
createdAt = datetime.fromtimestamp(int(pool["createdAtTimestamp"])).isoformat()
feePct = float(pool["feesUSD"]) / float(pool["volumeUSD"])
3000 / 1e6
# Out:
# 0.003

# %% [markdown]
# ## Position

# %%
op = Operation(schema.Query)
positions = op.positions(first=10, where={"pool": "0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8"})

positions.tick_lower(id="0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8")

positions.__fields__(
    pool=False,
    token0=False,
    token1=False,
    mints=False,
    burns=False,
    collects=False,
    swaps=False,
    tick_lower=False
)


# positions.tick_upper(where={"tickIdx_gte": "200004"})

# tick_lowers.__fields__(
#     pool=False
# )

# tick_uppers.__fields__(
#     pool=False
# )
endpoint(op)
# op
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3850/4015337133.py in <module>
#      25 #     pool=False
#      26 # )
# ---> 27 endpoint(op)
#      28 # op
#
# ~/.local/share/virtualenvs/uniswap_eda-kVjVZGgO/lib/python3.8/site-packages/sgqlc/endpoint/http.py in __call__(self, query, variables, operation_name, extra_headers, timeout)
#     140             # allows sgqlc.operation.Operation to be passed
#     141             # and generate compact representation of the queries
# --> 142             query = bytes(query).decode('utf-8')
#     143
#     144         headers = self.base_headers.copy()
#
# ~/.local/share/virtualenvs/uniswap_eda-kVjVZGgO/lib/python3.8/site-packages/sgqlc/operation/__init__.py in __bytes__(self)
#    2235
#    2236     def __bytes__(self):
# -> 2237         return bytes(self.__to_graphql__(indent_string=''), 'utf-8')
#    2238
#    2239     def __add__(self, other):
#
# ~/.local/share/virtualenvs/uniswap_eda-kVjVZGgO/lib/python3.8/site-packages/sgqlc/operation/__init__.py in __to_graphql__(self, indent, indent_string, auto_select_depth)
#    2199
#    2200         args = self.__args.__to_graphql__(indent, indent_string)
# -> 2201         selections = self.__selection_list.__to_graphql__(
#    2202             indent, indent_string, auto_select_depth)
#    2203
#
# ~/.local/share/virtualenvs/uniswap_eda-kVjVZGgO/lib/python3.8/site-packages/sgqlc/operation/__init__.py in __to_graphql__(self, indent, indent_string, auto_select_depth)
#    1848         s = ['{']
#    1849         for v in self.__selections:
# -> 1850             s.append(v.__to_graphql__(
#    1851                 next_indent, indent_string, auto_select_depth,
#    1852             ))
#
# ~/.local/share/virtualenvs/uniswap_eda-kVjVZGgO/lib/python3.8/site-packages/sgqlc/operation/__init__.py in __to_graphql__(self, indent, indent_string, auto_select_depth)
#    1553                 selections = self.__get_all_fields_selection_list(
#    1554                     auto_select_depth, [])
# -> 1555             query = ' ' + selections.__to_graphql__(
#    1556                 indent, indent_string, auto_select_depth)
#    1557         return prefix + alias + self.__field__.graphql_name + args + query
#
# ~/.local/share/virtualenvs/uniswap_eda-kVjVZGgO/lib/python3.8/site-packages/sgqlc/operation/__init__.py in __to_graphql__(self, indent, indent_string, auto_select_depth)
#    1848         s = ['{']
#    1849         for v in self.__selections:
# -> 1850             s.append(v.__to_graphql__(
#    1851                 next_indent, indent_string, auto_select_depth,
#    1852             ))
#
# ~/.local/share/virtualenvs/uniswap_eda-kVjVZGgO/lib/python3.8/site-packages/sgqlc/operation/__init__.py in __to_graphql__(self, indent, indent_string, auto_select_depth)
#    1544             alias = self.__alias__ + ': '
#    1545
# -> 1546         args = self.__field__.args.__to_graphql_input__(
#    1547             self.__args__, indent, indent_string)
#    1548
#
# ~/.local/share/virtualenvs/uniswap_eda-kVjVZGgO/lib/python3.8/site-packages/sgqlc/types/__init__.py in __to_graphql_input__(self, values, indent, indent_string)
#    2391             args = []
#    2392             for k, v in values.items():
# -> 2393                 p = self[k]
#    2394                 args.append(p.__to_graphql_input__(v))
#    2395             s.extend((', '.join(args), ')'))
#
# KeyError: 'id'

# %%
positions
# Out:
# [{'collectedFeesToken0': '0',
#   'collectedFeesToken1': '0',
#   'depositedToken0': '11',
#   'depositedToken1': '0.006256923560032086',
#   'feeGrowthInside0LastX128': '11051946651142285490120434851970',
#   'feeGrowthInside1LastX128': '2853664887402123112825648144657839284339',
#   'id': '10023',
#   'liquidity': '395460364753',
#   'owner': '0xafbad32c97e97075587566a691c5b613db35a596',
#   'tickLower': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12379317',
#    'createdAtTimestamp': '1620284794',
#    'feeGrowthOutside0X128': '7754172485245761590668832257383',
#    'feeGrowthOutside1X128': '1985458784020810623645127911188459111286',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#138180',
#    'liquidityGross': '5993742055125482',
#    'liquidityNet': '5993742055125482',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '1001800.206521985192235782332949707',
#    'price1': '0.0000009982030283980125277907193198057797',
#    'tickIdx': '138180',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'tickUpper': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12376367',
#    'createdAtTimestamp': '1620245933',
#    'feeGrowthOutside0X128': '0',
#    'feeGrowthOutside1X128': '0',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#207240',
#    'liquidityGross': '324938362447654679',
#    'liquidityNet': '-324937627698063161',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '999698077.7161172051593386186226232',
#    'price1': '0.000000001000302013468478961373148414637455',
#    'tickIdx': '207240',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'transaction': {'blockNumber': '12391094',
#    'burns': [],
#    'collects': [],
#    'flashed': [],
#    'gasPrice': '67000001561',
#    'gasUsed': '536870',
#    'id': '0x1df913510bdf69ea147ce020695130c25a42058433a6f0ac2e6b71fc305b66be',
#    'mints': [{'amount': '395460364753',
#      'amount0': '11',
#      'amount1': '0.006256923560032086',
#      'amountUSD': '33.10882740753563262931637786722105',
#      'id': '0x1df913510bdf69ea147ce020695130c25a42058433a6f0ac2e6b71fc305b66be#2888',
#      'logIndex': '111',
#      'origin': '0xafbad32c97e97075587566a691c5b613db35a596',
#      'owner': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'sender': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'tickLower': '138180',
#      'tickUpper': '207240',
#      'timestamp': '1620442906'}],
#    'swaps': [],
#    'timestamp': '1620442906'},
#   'withdrawnToken0': '0',
#   'withdrawnToken1': '0'},
#  {'collectedFeesToken0': '0',
#   'collectedFeesToken1': '0',
#   'depositedToken0': '5204.166976',
#   'depositedToken1': '0.999999999881002319',
#   'feeGrowthInside0LastX128': '15185624337567600620948650828081',
#   'feeGrowthInside1LastX128': '4128055580605567732202996755911628292000',
#   'id': '10029',
#   'liquidity': '2617235614963742',
#   'owner': '0x38f48a25d6c156bea5e1f7f6287bcba4206f94a2',
#   'tickLower': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12376766',
#    'createdAtTimestamp': '1620251377',
#    'feeGrowthOutside0X128': '116477239946740292061088075626136',
#    'feeGrowthOutside1X128': '29375319396659441377173334453079308034592',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#194160',
#    'liquidityGross': '316380125162095958',
#    'liquidityNet': '-247795184813266950',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '270296284.3380663294328360617828941',
#    'price1': '0.000000003699643901687064872664241937222553',
#    'tickIdx': '194160',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'tickUpper': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12375774',
#    'createdAtTimestamp': '1620238225',
#    'feeGrowthOutside0X128': '192341786496451687742460157718459',
#    'feeGrowthOutside1X128': '51436781036909019185720827915078621435189',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#195300',
#    'liquidityGross': '85085318275139648',
#    'liquidityNet': '72885937630739542',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '302933408.409936670866852218251531',
#    'price1': '0.000000003301055519920656257949206478365567',
#    'tickIdx': '195300',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'transaction': {'blockNumber': '12391104',
#    'burns': [],
#    'collects': [],
#    'flashed': [],
#    'gasPrice': '63000000000',
#    'gasUsed': '518028',
#    'id': '0x2f95a5c0d785d3430d1c30258cf9f8f9d12fcd3745a454a703866387d17b491f',
#    'mints': [{'amount': '2617235614963742',
#      'amount0': '5204.166976',
#      'amount1': '0.999999999881002319',
#      'amountUSD': '8737.665059008602013143178251528896',
#      'id': '0x2f95a5c0d785d3430d1c30258cf9f8f9d12fcd3745a454a703866387d17b491f#2889',
#      'logIndex': '80',
#      'origin': '0x38f48a25d6c156bea5e1f7f6287bcba4206f94a2',
#      'owner': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'sender': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'tickLower': '194160',
#      'tickUpper': '195300',
#      'timestamp': '1620443071'}],
#    'swaps': [],
#    'timestamp': '1620443071'},
#   'withdrawnToken0': '0',
#   'withdrawnToken1': '0'},
#  {'collectedFeesToken0': '0',
#   'collectedFeesToken1': '0',
#   'depositedToken0': '12.567122',
#   'depositedToken1': '0.002999999938795123',
#   'feeGrowthInside0LastX128': '9368554870489765704755975662108',
#   'feeGrowthInside1LastX128': '2707192079635065936280599159579118186638',
#   'id': '10038',
#   'liquidity': '16338467085711',
#   'owner': '0xd2dd7245c974a121135ed2975bd594297f6c358c',
#   'tickLower': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12377108',
#    'createdAtTimestamp': '1620255494',
#    'feeGrowthOutside0X128': '134063313340362922801725428550174',
#    'feeGrowthOutside1X128': '34034394388805957717313390956009053793343',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#194400',
#    'liquidityGross': '5786078962659685',
#    'liquidityNet': '5786078962659685',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '276861534.7973979780731759064035929',
#    'price1': '0.000000003611913806415113028269215527717886',
#    'tickIdx': '194400',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'tickUpper': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12375999',
#    'createdAtTimestamp': '1620241329',
#    'feeGrowthOutside0X128': '164581124069751849037846005070468',
#    'feeGrowthOutside1X128': '42973614232442701503650348589843459773333',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#194880',
#    'liquidityGross': '219687644550444651',
#    'liquidityNet': '-176182555240390975',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '290474300.8048387498877397599934688',
#    'price1': '0.000000003442645346694098661602342078788193',
#    'tickIdx': '194880',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'transaction': {'blockNumber': '12391122',
#    'burns': [],
#    'collects': [],
#    'flashed': [],
#    'gasPrice': '59000001459',
#    'gasUsed': '483113',
#    'id': '0x13a8fedec19018f96f8653b46df8db8eb656d07767f1e7a53a06dabb77dda434',
#    'mints': [{'amount': '16338467085711',
#      'amount0': '12.567122',
#      'amount1': '0.002999999938795123',
#      'amountUSD': '23.16761603401992469665496474490265',
#      'id': '0x13a8fedec19018f96f8653b46df8db8eb656d07767f1e7a53a06dabb77dda434#2891',
#      'logIndex': '370',
#      'origin': '0xd2dd7245c974a121135ed2975bd594297f6c358c',
#      'owner': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'sender': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'tickLower': '194400',
#      'tickUpper': '194880',
#      'timestamp': '1620443370'}],
#    'swaps': [],
#    'timestamp': '1620443370'},
#   'withdrawnToken0': '0',
#   'withdrawnToken1': '0'},
#  {'collectedFeesToken0': '2383.767443',
#   'collectedFeesToken1': '0',
#   'depositedToken0': '1428',
#   'depositedToken1': '0.269257552360852256',
#   'feeGrowthInside0LastX128': '694992185773508097502178252214',
#   'feeGrowthInside1LastX128': '418297853130110333547502698851247711813',
#   'id': '10091',
#   'liquidity': '0',
#   'owner': '0x679641f9450609d2ca03b2c468ac8631f87d8ee6',
#   'tickLower': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12376277',
#    'createdAtTimestamp': '1620244686',
#    'feeGrowthOutside0X128': '140010936837048065499143907714359',
#    'feeGrowthOutside1X128': '35750072780938251323116875140416987560026',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#194580',
#    'liquidityGross': '12872663982852156',
#    'liquidityNet': '8065091284169002',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '281889910.6330435875893366593319199',
#    'price1': '0.000000003547484185419364192019821191033586',
#    'tickIdx': '194580',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'tickUpper': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12375709',
#    'createdAtTimestamp': '1620237397',
#    'feeGrowthOutside0X128': '146073399371038534983362531745892',
#    'feeGrowthOutside1X128': '37793680720954957837469811937843453551512',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#194700',
#    'liquidityGross': '482723730793302045',
#    'liquidityNet': '470188996267722849',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '285292795.8983205040283090209137',
#    'price1': '0.000000003505170878399621447890758656624528',
#    'tickIdx': '194700',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'transaction': {'blockNumber': '12391223',
#    'burns': [],
#    'collects': [],
#    'flashed': [],
#    'gasPrice': '54000000000',
#    'gasUsed': '447603',
#    'id': '0x3bb99c8b2f533c7a8094ef7f5dcbc7cf443b5a8373a51713606df196efeae015',
#    'mints': [{'amount': '6682724804612278',
#      'amount0': '1428',
#      'amount1': '0.269257552360852256',
#      'amountUSD': '2378.618849174701399597766382249821',
#      'id': '0x3bb99c8b2f533c7a8094ef7f5dcbc7cf443b5a8373a51713606df196efeae015#2893',
#      'logIndex': '265',
#      'origin': '0x679641f9450609d2ca03b2c468ac8631f87d8ee6',
#      'owner': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'sender': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'tickLower': '194580',
#      'tickUpper': '194700',
#      'timestamp': '1620444593'}],
#    'swaps': [],
#    'timestamp': '1620444593'},
#   'withdrawnToken0': '2380.900141',
#   'withdrawnToken1': '0'},
#  {'collectedFeesToken0': '732.12986',
#   'collectedFeesToken1': '0',
#   'depositedToken0': '732.129861',
#   'depositedToken1': '0',
#   'feeGrowthInside0LastX128': '115792089237316195423570985008687907853269984661129425192633351083143738185094',
#   'feeGrowthInside1LastX128': '115792089237316195423570985008687907852199287001381217322266210877989831992544',
#   'id': '10110',
#   'liquidity': '0',
#   'owner': '0xbaec09ba4b3249b3153767d113885b7d277d0041',
#   'tickLower': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12377796',
#    'createdAtTimestamp': '1620264804',
#    'feeGrowthOutside0X128': '148190278105494144039084819361253',
#    'feeGrowthOutside1X128': '38131403610677038491262223836761524756607',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#194640',
#    'liquidityGross': '153359718491218393',
#    'liquidityNet': '149858851239210907',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '283586249.2082941440809660332138266',
#    'price1': '0.000000003526264065312630319787607056076152',
#    'tickIdx': '194640',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'tickUpper': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12375709',
#    'createdAtTimestamp': '1620237397',
#    'feeGrowthOutside0X128': '146073399371038534983362531745892',
#    'feeGrowthOutside1X128': '37793680720954957837469811937843453551512',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#194700',
#    'liquidityGross': '482723730793302045',
#    'liquidityNet': '470188996267722849',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '285292795.8983205040283090209137',
#    'price1': '0.000000003505170878399621447890758656624528',
#    'tickIdx': '194700',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'transaction': {'blockNumber': '12391271',
#    'burns': [],
#    'collects': [],
#    'flashed': [],
#    'gasPrice': '55000000000',
#    'gasUsed': '701938',
#    'id': '0xaabc6b06fa2ed421bb2e7b99fd251adba18ec893f8f182930ec3c47225e9bdd8',
#    'mints': [{'amount': '4116066761061957',
#      'amount0': '732.129861',
#      'amount1': '0',
#      'amountUSD': '732.1298609999999999999999999999999',
#      'id': '0xaabc6b06fa2ed421bb2e7b99fd251adba18ec893f8f182930ec3c47225e9bdd8#2898',
#      'logIndex': '68',
#      'origin': '0xbaec09ba4b3249b3153767d113885b7d277d0041',
#      'owner': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'sender': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'tickLower': '194640',
#      'tickUpper': '194700',
#      'timestamp': '1620445271'}],
#    'swaps': [],
#    'timestamp': '1620445271'},
#   'withdrawnToken0': '732.12986',
#   'withdrawnToken1': '0'},
#  {'collectedFeesToken0': '1214.812973',
#   'collectedFeesToken1': '7.041089219059131528',
#   'depositedToken0': '12300',
#   'depositedToken1': '2.714955030566441462',
#   'feeGrowthInside0LastX128': '195873354329756183330041496968348',
#   'feeGrowthInside1LastX128': '57455250990156464955501589670911232205174',
#   'id': '1012',
#   'liquidity': '0',
#   'owner': '0x2a4e6c78f12333481a6d932ba526eb56bd64f008',
#   'tickLower': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12376596',
#    'createdAtTimestamp': '1620249034',
#    'feeGrowthOutside0X128': '35867906140686191388541808251546',
#    'feeGrowthOutside1X128': '8467025802246916369498319139407104362088',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#193320',
#    'liquidityGross': '271447980514020972',
#    'liquidityNet': '242231088867710810',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '248519895.9385842392525156361147878',
#    'price1': '0.000000004023822705314210064532912910850421',
#    'tickIdx': '193320',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'tickUpper': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12376763',
#    'createdAtTimestamp': '1620251369',
#    'feeGrowthOutside0X128': '263364505071282130060099189625221',
#    'feeGrowthOutside1X128': '77018402513723414332216393512644893815026',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#196980',
#    'liquidityGross': '50526193357653111',
#    'liquidityNet': '26279338200191561',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '358348009.4611790165950956408753442',
#    'price1': '0.000000002790583381511243447115198422342696',
#    'tickIdx': '196980',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'transaction': {'blockNumber': '12376763',
#    'burns': [],
#    'collects': [],
#    'flashed': [],
#    'gasPrice': '65000000000',
#    'gasUsed': '547495',
#    'id': '0x8d4f5d48ef896fde9e3b66857c570c46fb6755c19c2206b3cc8ab973e4774e9f',
#    'mints': [{'amount': '2111757456902815',
#      'amount0': '12300',
#      'amount1': '2.714955030566441462',
#      'amountUSD': '21596.74413391555283172658464402571',
#      'id': '0x8d4f5d48ef896fde9e3b66857c570c46fb6755c19c2206b3cc8ab973e4774e9f#220',
#      'logIndex': '167',
#      'origin': '0x2a4e6c78f12333481a6d932ba526eb56bd64f008',
#      'owner': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'sender': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'tickLower': '193320',
#      'tickUpper': '196980',
#      'timestamp': '1620251369'}],
#    'swaps': [],
#    'timestamp': '1620251369'},
#   'withdrawnToken0': '0',
#   'withdrawnToken1': '6.684912487521409381'},
#  {'collectedFeesToken0': '407.407191',
#   'collectedFeesToken1': '3.045805182425191224',
#   'depositedToken0': '4809.898909',
#   'depositedToken1': '1.351116656862945905',
#   'feeGrowthInside0LastX128': '230620418925018464923290003255442',
#   'feeGrowthInside1LastX128': '68164396558266389921442029411062718667429',
#   'id': '10136',
#   'liquidity': '0',
#   'owner': '0xb47bccc4b7343b385ce09064649246b09c2549ff',
#   'tickLower': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12391338',
#    'createdAtTimestamp': '1620446098',
#    'feeGrowthOutside0X128': '18808215310863954217962461483429',
#    'feeGrowthOutside1X128': '4846390009764506962847103497422267054328',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#191760',
#    'liquidityGross': '187570150919635021',
#    'liquidityNet': '187570150919635021',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '212625139.3193676264365355587024371',
#    'price1': '0.000000004703112732582284401148572731985353',
#    'tickIdx': '191760',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'tickUpper': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12378621',
#    'createdAtTimestamp': '1620275218',
#    'feeGrowthOutside0X128': '352390718310650982825518089502160',
#    'feeGrowthOutside1X128': '110372816518961005518871899793594795466073',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#197520',
#    'liquidityGross': '174132435591223010',
#    'liquidityNet': '166235677156603058',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '378229785.0454755604556490728642795',
#    'price1': '0.000000002643895429546267419302407508638183',
#    'tickIdx': '197520',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'transaction': {'blockNumber': '12391338',
#    'burns': [],
#    'collects': [],
#    'flashed': [],
#    'gasPrice': '47300001358',
#    'gasUsed': '823407',
#    'id': '0x68bcd35c8ffc38bcd2ee682e210b3f5da370f46b060c23bbb56df995a8281b00',
#    'mints': [{'amount': '601132735649428',
#      'amount0': '4809.898909',
#      'amount1': '1.351116656862945905',
#      'amountUSD': '9580.370368530117378360721788749843',
#      'id': '0x68bcd35c8ffc38bcd2ee682e210b3f5da370f46b060c23bbb56df995a8281b00#2899',
#      'logIndex': '199',
#      'origin': '0xb47bccc4b7343b385ce09064649246b09c2549ff',
#      'owner': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'sender': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'tickLower': '191760',
#      'tickUpper': '197520',
#      'timestamp': '1620446098'}],
#    'swaps': [],
#    'timestamp': '1620446098'},
#   'withdrawnToken0': '0',
#   'withdrawnToken1': '2.925387981417289753'},
#  {'collectedFeesToken0': '0',
#   'collectedFeesToken1': '0',
#   'depositedToken0': '0',
#   'depositedToken1': '0.000999999999998862',
#   'feeGrowthInside0LastX128': '115792089237316195423570985008687907853269984664325035816176711771961710319737',
#   'feeGrowthInside1LastX128': '115792089237316195423570985008687907853194680980095711754027107026815481143944',
#   'id': '10137',
#   'liquidity': '601997327259',
#   'owner': '0xad226e9704a3effb8976ee11bc823b570e160ace',
#   'tickLower': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12375970',
#    'createdAtTimestamp': '1620240866',
#    'feeGrowthOutside0X128': '1315528223280872235951419320199',
#    'feeGrowthOutside1X128': '75303685544852285430476981097648495992',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#191160',
#    'liquidityGross': '312358894094708880',
#    'liquidityNet': '288529482192228984',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '200243415.8486910458058154877440009',
#    'price1': '0.000000004993922001188918567625835612512806',
#    'tickIdx': '191160',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'tickUpper': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12370624',
#    'createdAtTimestamp': '1620169800',
#    'feeGrowthOutside0X128': '37955142658700363660360883549857',
#    'feeGrowthOutside1X128': '9211802863519692205948838089770480923562',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#193380',
#    'liquidityGross': '688659531063565819',
#    'liquidityNet': '270286917223453219',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '250015422.6328569819884280427193744',
#    'price1': '0.000000003999753253096235909587685196780323',
#    'tickIdx': '193380',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'transaction': {'blockNumber': '12391339',
#    'burns': [],
#    'collects': [],
#    'flashed': [],
#    'gasPrice': '41000001459',
#    'gasUsed': '412112',
#    'id': '0xb019c96811ac92e493fa2c22424a6e617ae6b2c69ff5f7726d41339b39af6e42',
#    'mints': [{'amount': '601997327259',
#      'amount0': '0',
#      'amount1': '0.000999999999998862',
#      'amountUSD': '3.530762081344537804450121975778045',
#      'id': '0xb019c96811ac92e493fa2c22424a6e617ae6b2c69ff5f7726d41339b39af6e42#2900',
#      'logIndex': '218',
#      'origin': '0xad226e9704a3effb8976ee11bc823b570e160ace',
#      'owner': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'sender': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'tickLower': '191160',
#      'tickUpper': '193380',
#      'timestamp': '1620446111'}],
#    'swaps': [],
#    'timestamp': '1620446111'},
#   'withdrawnToken0': '0',
#   'withdrawnToken1': '0'},
#  {'collectedFeesToken0': '14468.656314',
#   'collectedFeesToken1': '3.604314259770292937',
#   'depositedToken0': '12065.595935',
#   'depositedToken1': '4.092944345952664707',
#   'feeGrowthInside0LastX128': '87639101472996389388024890707333',
#   'feeGrowthInside1LastX128': '21828178400584230694474132897797162176942',
#   'id': '10140',
#   'liquidity': '0',
#   'owner': '0xa4096b2f2f8dfb059353e86c1383b2604e57b17a',
#   'tickLower': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12391343',
#    'createdAtTimestamp': '1620446179',
#    'feeGrowthOutside0X128': '771898924715078716122457993949735',
#    'feeGrowthOutside1X128': '299686152818024558401586591746381951788873',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#190440',
#    'liquidityGross': '1060556690008731',
#    'liquidityNet': '1060556690008731',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '186333355.8841355235980282330004355',
#    'price1': '0.000000005366725647456340866503589721663853',
#    'tickIdx': '190440',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'tickUpper': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12375970',
#    'createdAtTimestamp': '1620240866',
#    'feeGrowthOutside0X128': '443771102619256883244158186221152',
#    'feeGrowthOutside1X128': '146393055468898705363937203314232497166095',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#198060',
#    'liquidityGross': '896621084772820498',
#    'liquidityNet': '68216066911072294',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '399214636.3828052815900157529834004',
#    'price1': '0.000000002504918179004599648811960755859735',
#    'tickIdx': '198060',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'transaction': {'blockNumber': '12391343',
#    'burns': [],
#    'collects': [],
#    'flashed': [],
#    'gasPrice': '43000000000',
#    'gasUsed': '517088',
#    'id': '0x5677175e351cbccc2adf852d5eb42271ebcce442f00550fda2a64b673920c55e',
#    'mints': [{'amount': '1287538218638422',
#      'amount0': '12065.595935',
#      'amount1': '4.092944345952664707',
#      'amountUSD': '26516.80863275963390712369731223418',
#      'id': '0x5677175e351cbccc2adf852d5eb42271ebcce442f00550fda2a64b673920c55e#2901',
#      'logIndex': '274',
#      'origin': '0xa4096b2f2f8dfb059353e86c1383b2604e57b17a',
#      'owner': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'sender': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'tickLower': '190440',
#      'tickUpper': '198060',
#      'timestamp': '1620446179'}],
#    'swaps': [],
#    'timestamp': '1620446179'},
#   'withdrawnToken0': '14137.0532',
#   'withdrawnToken1': '3.52172222249161798'},
#  {'collectedFeesToken0': '0',
#   'collectedFeesToken1': '0',
#   'depositedToken0': '2',
#   'depositedToken1': '0.000234077705420269',
#   'feeGrowthInside0LastX128': '17425990205795743479483718568427',
#   'feeGrowthInside1LastX128': '4696180316041119301891771921134188758544',
#   'id': '10141',
#   'liquidity': '34235428827',
#   'owner': '0x04ee321ee32021c6607a5e6421b3e09008bebc08',
#   'tickLower': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12376031',
#    'createdAtTimestamp': '1620241725',
#    'feeGrowthOutside0X128': '1382225105068210738478742915002',
#    'feeGrowthOutside1X128': '150209693723387660955331576288078295784',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#184200',
#    'liquidityGross': '45888023979094479',
#    'liquidityNet': '45888023979094479',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '99839959.94519880714766083090761372',
#    'price1': '0.00000001001602965935573665070681837168992',
#    'tickIdx': '184200',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'tickUpper': {'collectedFeesToken0': '0',
#    'collectedFeesToken1': '0',
#    'collectedFeesUSD': '0',
#    'createdAtBlockNumber': '12373953',
#    'createdAtTimestamp': '1620214068',
#    'feeGrowthOutside0X128': '0',
#    'feeGrowthOutside1X128': '0',
#    'feesUSD': '0',
#    'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8#276300',
#    'liquidityGross': '577836006020705356',
#    'liquidityNet': '-577163053951579692',
#    'liquidityProviderCount': '0',
#    'poolAddress': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#    'price0': '997600359915.0460742437634054727477',
#    'price1': '0.000000000001002405412208510304633823031144294',
#    'tickIdx': '276300',
#    'untrackedVolumeUSD': '0',
#    'volumeToken0': '0',
#    'volumeToken1': '0',
#    'volumeUSD': '0'},
#   'transaction': {'blockNumber': '12391346',
#    'burns': [],
#    'collects': [],
#    'flashed': [],
#    'gasPrice': '55000000233',
#    'gasUsed': '502196',
#    'id': '0xdd2efff4fa2b4d0e6ed470d7edfe3a439b7a3bb1184e0443c956425662d54308',
#    'mints': [{'amount': '34235428827',
#      'amount0': '2',
#      'amount1': '0.000234077705420269',
#      'amountUSD': '2.826472686386963098633119261604883',
#      'id': '0xdd2efff4fa2b4d0e6ed470d7edfe3a439b7a3bb1184e0443c956425662d54308#2902',
#      'logIndex': '171',
#      'origin': '0x04ee321ee32021c6607a5e6421b3e09008bebc08',
#      'owner': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'sender': '0xc36442b4a4522e871399cd717abdd847ab11fe88',
#      'tickLower': '184200',
#      'tickUpper': '276300',
#      'timestamp': '1620446254'}],
#    'swaps': [],
#    'timestamp': '1620446254'},
#   'withdrawnToken0': '0',
#   'withdrawnToken1': '0'}]

# %% [markdown]
# ## Transactions

# %%
op = Operation(schema.Query)
candles = op.transactions(where={"pool": "0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8", "timestamp_lte": 1621810558}, order_by="timestamp", order_direction="desc", first=10)
# candles = op.transactions(where={"pool": "0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8"}, order_direction="desc", first=10, skip=5000)
candles.__fields__(
    id=True,
    timestamp=True
    # high=True,
    # low=True,
    # close=True
)

# data = endpoint(op)
# len(data["data"]["transactions"])
endpoint(op)
# Out:
# {'data': {'transactions': [{'id': '0x3db003c57ca942913c3a5616ff14595c5f227b3b4b873e9ec46a80c68b249b8e',
#     'timestamp': '1621810556'},
#    {'id': '0xd6596fe0d76eb3f5c7e7661c7cf94f388ce3936ff8276e1825e4362c7faccfa1',
#     'timestamp': '1621810536'},
#    {'id': '0xc9e279af85e5554cd0cd9a8035335a3145860789475451471fa96ff6d1454564',
#     'timestamp': '1621810536'},
#    {'id': '0x9d99dc432462a0e29c792a9684160b2e0c5935d3104055f1a0b61f80579ef026',
#     'timestamp': '1621810536'},
#    {'id': '0x6541e62e6bfd529b4d36e31f05f153445bb7a108f3a154192ab1490618dc7009',
#     'timestamp': '1621810536'},
#    {'id': '0x33576ef5b5fb928be6e5bbf0ee56b974919d5668c60ea0b6d327d7b632f0f12c',
#     'timestamp': '1621810536'},
#    {'id': '0x1542197d71a0ca5574380661583f9554abe21573308067475f48814233e47966',
#     'timestamp': '1621810536'},
#    {'id': '0xbc99f2c5b914d08f37b25df50b7f8a7707f135d32d4cf41bfe73afb8f0526310',
#     'timestamp': '1621810535'},
#    {'id': '0xb639cb319d9f619e2ca0ec7dfaa705fa7681d6b8298a379c1b824997ad28ffdf',
#     'timestamp': '1621810535'},
#    {'id': '0x2ed40e22b0e11b3a69955f291884bbcc30fe091cd6b4655a7394c104f6df812e',
#     'timestamp': '1621810535'}]}}

# %% [markdown]
# ## Top Pools

# %%
op = Operation(schema.Query)
pools = op.pools(order_by="totalValueLockedUSD", order_direction="desc", first=10)
pools.__fields__(
    mints=False,
    burns=False,
    swaps=False,
    pool_hour_data=False,
    pool_day_data=False,
    ticks=False,
    collects=False
)
pools.token0.__fields__(
    symbol=True,
    name=True,
    decimals=True,
    total_supply=True
)
pools.token1.__fields__(
    symbol=True,
    name=True,
    decimals=True,
    total_supply=True
)
# pool_hour_data = pools.pool_hour_data(first=5, order_by="periodStartUnix", order_direction="desc").__fields__(pool=False)
# pools.ticks(first=5, order_by="tickIdx", order_direction="desc", where={"tick_idx_lt": 200401}).__fields__(pool=False)
data = endpoint(op)
pools = data["data"]["pools"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_17628/3960663366.py in <module>
# ----> 1 op = Operation(schema.Query)
#       2 pools = op.pools(order_by="totalValueLockedUSD", order_direction="desc", first=10)
#       3 pools.__fields__(
#       4     mints=False,
#       5     burns=False,
#
# NameError: name 'Operation' is not defined

# %%
pool_recs = []
for p in pools:
    pool_rec = {}
    pool_rec["id"] = p["id"]
    pool_rec["token0"] = p["token0"]["symbol"]
    pool_rec["token1"] = p["token1"]["symbol"]
    pool_rec["tvlUSD_MM"] = round(float(p["totalValueLockedUSD"]) / 1e6,1)
    pool_rec["tok0Dec"] = int(p["token0"]["decimals"])
    pool_rec["tok11Dec"] = int(p["token1"]["decimals"])
    pool_rec["token1Price"] = round(float(p["token1Price"]), 6)
    pool_rec["token0Price"] = round(float(p["token0Price"]), 6)
    
    pool_rec["sqrtPrice"] = int(p["sqrtPrice"])
    pool_rec["tok1Price_sqrtPrice"] = utils.sqrt_price_to_tick(p["sqrtPrice"], p["token0"]["decimals"], p["token1"]["decimals"]) 
    pool_rec["tok0Price_sqrtPrice"] = 1 / utils.sqrt_price_to_tick(p["sqrtPrice"], p["token0"]["decimals"], p["token1"]["decimals"])
    pool_rec["tick"] = int(p["tick"])
    pool_rec["token1Price_tick"] = utils.tick_to_price(p["tick"], p["token0"]["decimals"], p["token1"]["decimals"])
    pool_rec["token0Price_tick"] = 1 / utils.tick_to_price(p["tick"], p["token0"]["decimals"], p["token1"]["decimals"])
    pool_recs.append(pool_rec)
pd.DataFrame(pool_recs)
# Out:
#                                            id token0 token1  tvlUSD_MM  \
# 0  0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8   USDC   WETH      262.6
# 1  0x7858e59e0c01ea06df3af3d20ac7b0003275d4bf   USDC   USDT      188.8
# 2  0xcbcdf9626bc03e24f779434178a73a0b4bad62ed   WBTC   WETH      149.6
# 3  0x6c6bc977e13df9b0de53b251522280bb72383700    DAI   USDC      117.8
# 4  0x4e68ccd3e89f51c3074ca5072bbac773960dfa36   WETH   USDT      112.8
# 5  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640   USDC   WETH      107.3
# 6  0x1d42064fc4beb5f8aaf85f4617ae8b3b5b8bd801    UNI   WETH       57.4
# 7  0x99ac8ca7087fa4a2a1fb6357269965a2014abc35   WBTC   USDC       53.7
# 8  0x6f48eca74b38d2936b02ab603ff4e36a6c0e3a77    DAI   USDT       34.8
# 9  0x8f8ef111b67c04eb1641f5ff19ee54cda062f163   WBTC    PAX       34.5
#
#    tok0Dec  tok11Dec   token1Price  token0Price  \
# 0        6        18      0.000484  2066.255632
# 1        6         6      1.000200     0.999800
# 2        8        18     15.855103     0.063071
# 3       18         6      1.000634     0.999366
# 4       18         6   2064.881344     0.000484
# 5        6        18      0.000483  2068.881685
# 6       18        18      0.008699   114.958410
# 7        8         6  32675.404388     0.000031
# 8       18         6      1.000645     0.999355
# 9        8        18  32669.670987     0.000031
#
#                                sqrtPrice  tok1Price_sqrtPrice  \
# 0     1742960554604975746812629187750013             0.000484
# 1          79236081571290040430959097622             1.000200
# 2    31547439728262583459360356042537943            15.855103
# 3                79253279332169081581262             1.000634
# 4              3600204197638584562734859          2064.881344
# 5     1741854024512922358092938238159909             0.000483
# 6           7389400580308568819619073728             0.008699
# 7        1432155150780408377639915877657         32675.404388
# 8                79253712331600947372848             1.000645
# 9  1432029498464517166380285248000000000         32669.670987
#
#    tok0Price_sqrtPrice    tick  token1Price_tick  token0Price_tick
# 0          2066.255632  199985          0.000484       2066.312660
# 1             0.999800       1          1.000100          0.999900
# 2             0.063071  257906         15.854599          0.063073
# 3             0.999366 -276318          1.000603          0.999398
# 4             0.000484 -199992       2064.866820          0.000484
# 5          2068.881685  199972          0.000483       2069.000479
# 6           114.958410  -47449          0.008698        114.969028
# 7             0.000031   57894      32672.229173          0.000031
# 8             0.999355 -276318          1.000603          0.999398
# 9             0.000031  334217      32668.875905          0.000031

# %%
accumulator_delta = float(pool["ticks"][0]["price0"]) - float(pool["ticks"][1]["price0"])
accumulator_delta
# Out:
# 3017544.2882022858

# %%
P = float(pool["totalValueLockedToken0"]) / float(pool["totalValueLockedToken1"])
P
# Out:
# 1263.6335317133787

# %%
1.0001 ** (accumulator_delta / (60 * 60))
# Out:
# 1.0874293147290275

# %%
float(pool["totalValueLockedToken0"]) * float(pool["totalValueLockedToken1"])
# Out:
# 7822359097369.466

# %%
float_cols = ["open", "high", "low", "close", "tvlUSD", "token0Price", "token1Price"]
int_cols = []
df_hourly = pd.DataFrame(pool["poolHourData"]).astype({fc: float for fc in float_cols})
df_hourly['dateTime'] = pd.to_datetime(df_hourly['periodStartUnix'],unit='s')
df_hourly
# Out:
#            close               feeGrowthGlobal0X128  \
# 0    1977.973473  874979102996300954639254533655225
# 1    1977.623948  874945415587848166303247496984956
# 2    1955.865401  874690117570771161772367726492384
# 3    1945.387827  874545958152337591452542879165510
# 4    1943.737562  874437759799881774259209905800226
# ..           ...                                ...
# 195  1942.968347  847645186763524894517975186999431
# 196  1926.517344  847418369384670465273104138021348
# 197  1966.409817  847331376612188759244029710822828
# 198  1991.831065  847331094630383847068287836131264
# 199  1992.428009  847331094630383847068287836131264
#
#                            feeGrowthGlobal1X128 feesUSD         high  \
# 0    350526631139346628401877253647519048631880       0  1980.551230
# 1    350511643866989506797553816068686360831201       0  1977.623948
# 2    350509515883741698380136440683059205716783       0  1957.761480
# 3    350498326407533841641649542080782446460676       0  1945.387827
# 4    350452060049857228339394360828448927565015       0  1963.717245
# ..                                          ...     ...          ...
# 195  336283888172957314616112121397072447415417       0  1942.968347
# 196  336264742589107028197855709318325633384793       0  1965.722094
# 197  335982848589224712851109510334043509555556       0  1991.830363
# 198  335834885553102697296478130920047728823840       0  1992.428009
# 199  335831448448238069853450395692787378663924       0  1999.450684
#
#                                                     id             liquidity  \
# 0    0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-451919  16827547024249704226
# 1    0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-451918  16798546947525575029
# 2    0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-451917  14869030150748591690
# 3    0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-451916  14737784200884702323
# 4    0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-451915  14660072282118470820
# ..                                                 ...                   ...
# 195  0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-451724  13306754957595312003
# 196  0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-451723  12969373854580066017
# 197  0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-451722  17404347783651843722
# 198  0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-451721  17117872078150877688
# 199  0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8-451720  17185683003825626626
#
#              low         open  periodStartUnix  \
# 0    1977.623948  1977.623948       1626908400
# 1    1955.510694  1955.581237       1626904800
# 2    1945.387827  1945.387827       1626901200
# 3    1938.133172  1942.339835       1626897600
# 4    1943.737562  1963.127285       1626894000
# ..           ...          ...              ...
# 195  1923.488703  1923.488703       1626206400
# 196  1925.028308  1965.722094       1626202800
# 197  1966.409817  1991.830363       1626199200
# 198  1991.831065  1992.428009       1626195600
# 199  1992.428009  1999.450684       1626192000
#
#                               sqrtPrice    tick  token0Price  token1Price  \
# 0    1781432422475807032952268090297621  200421  1977.973473     0.000506
# 1    1781589840477654114820610143114369  200423  1977.623948     0.000506
# 2    1791472317473467759980697920259631  200534  1955.865401     0.000511
# 3    1796290142931039666189921906336321  200588  1945.387827     0.000514
# 4    1797052520925717111937140078842364  200596  1943.737562     0.000514
# ..                                  ...     ...          ...          ...
# 195  1797408209772151303734129377873357  200600  1942.968347     0.000515
# 196  1805066150465717816513402848358857  200685  1926.517344     0.000519
# 197  1786662684228086127112999931843535  200480  1966.409817     0.000509
# 198  1775224704455328628136713983082123  200352  1991.831065     0.000502
# 199  1774958750272687547191398831484241  200349  1992.428009     0.000502
#
#            tvlUSD txCount volumeToken0 volumeToken1 volumeUSD  \
# 0    2.561168e+08      16            0            0         0
# 1    2.558838e+08      59            0            0         0
# 2    2.541562e+08      35            0            0         0
# 3    2.525898e+08      57            0            0         0
# 4    2.520735e+08      63            0            0         0
# ..            ...     ...          ...          ...       ...
# 195  2.639464e+08      44            0            0         0
# 196  2.638753e+08      83            0            0         0
# 197  2.676258e+08     103            0            0         0
# 198  2.700932e+08      27            0            0         0
# 199  2.702785e+08      71            0            0         0
#
#                dateTime
# 0   2021-07-21 23:00:00
# 1   2021-07-21 22:00:00
# 2   2021-07-21 21:00:00
# 3   2021-07-21 20:00:00
# 4   2021-07-21 19:00:00
# ..                  ...
# 195 2021-07-13 20:00:00
# 196 2021-07-13 19:00:00
# 197 2021-07-13 18:00:00
# 198 2021-07-13 17:00:00
# 199 2021-07-13 16:00:00
#
# [200 rows x 20 columns]

# %% [markdown]
# ## State
#
# Tracked at the following levels:
#
# * global - per pool
# * per-tick
# * per-position
